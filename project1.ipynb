# %%
import pandas as pd

# %%
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-7099f313-c7f2-4b42-82d1-d1c5ffcebe3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7099f313-c7f2-4b42-82d1-d1c5ffcebe3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("realtime_ddos_traffic_dataset (1).csv")

# %%
df = pd.read_csv("realtime_ddos_traffic_dataset (1).csv")
display(df.head())
# Out:
#   traffic_type  packet_count  packet_count_per_second  byte_count  \
# 0       Normal          4122                      112   188875963
# 1       Normal          4280                      943   697892057
# 2       Normal          6924                      754   534906109
# 3       Normal          3695                     1156   598962098
# 4       Normal          7147                      373   106331004
#
#    byte_count_per_second
# 0               32613090
# 1               13647750
# 2               32374543
# 3               30985275
# 4                9431993

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   traffic_type             2000 non-null   object
#  1   packet_count             2000 non-null   int64
#  2   packet_count_per_second  2000 non-null   int64
#  3   byte_count               2000 non-null   int64
#  4   byte_count_per_second    2000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 78.3+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("realtime_ddos_traffic_dataset (1).csv")
df.plot()
plt.show()

# %%
display(df.isnull().sum())
# Out:
# traffic_type               0
# packet_count               0
# packet_count_per_second    0
# byte_count                 0
# byte_count_per_second      0
# dtype: int64
